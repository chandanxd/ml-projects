# %%
# !where python
# Out:
# c:\Users\Admin\miniconda3\envs\general\python.exe
# C:\Users\Admin\miniconda3\python.exe
# C:\Users\Admin\AppData\Local\Microsoft\WindowsApps\python.exe

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# Standard imports
import os

# Third-party imports

# Local imports
